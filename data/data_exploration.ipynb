# %%
import pandas as pd 
import gzip

# %%
calendar_df = pd.read_csv('calendar.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
display(calendar_df.head(10))
display(calendar_df.shape)
# Out:
#    listing_id        date available   price  adjusted_price  minimum_nights
# 0        2818  2023-12-12         f  $59.00             NaN               3  \
# 1        2818  2023-12-13         f  $59.00             NaN               3
# 2        2818  2023-12-14         f  $59.00             NaN               3
# 3        2818  2023-12-15         f  $59.00             NaN               3
# 4        2818  2023-12-16         f  $59.00             NaN               3
# 5        2818  2023-12-17         f  $59.00             NaN               3
# 6        2818  2023-12-18         f  $59.00             NaN               3
# 7        2818  2023-12-19         f  $59.00             NaN               3
# 8        2818  2023-12-20         f  $59.00             NaN               3
# 9        2818  2023-12-21         f  $59.00             NaN               3
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125
# ...

# %%
calendar_df[['listing_id','date']].drop_duplicates()
# Out:
#                   listing_id        date
# 0                       2818  2023-12-12
# 1                       2818  2023-12-13
# 2                       2818  2023-12-14
# 3                       2818  2023-12-15
# 4                       2818  2023-12-16
# ...                      ...         ...
# 3189730  1043564085900406281  2024-12-06
# 3189731  1043564085900406281  2024-12-07
# 3189732  1043564085900406281  2024-12-08
# 3189733  1043564085900406281  2024-12-09
# 3189734  1043564085900406281  2024-12-10
#
# [3189735 rows x 2 columns]

# %%
calendar_df.adjusted_price.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
listing_df = pd.read_csv('listings.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
# display(listing_df.head(5))
# display(listing_df.columns)
# display(listing_df.shape)
# display(listing_df.host_id.dropna().value_counts)
# display(listing_df.neighbourhood_cleansed.dropna().value_counts)
# display(listing_df.neighbourhood_group_cleansed.dropna().value_counts)
# display(listing_df.accommodates.dropna().value_counts)
display(listing_df.amenities.value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#         ..
# 8734    []
# 8735    []
# 8736    []
# 8737    []
# 8738    []
# Name: amenities, Length: 8739, dtype: object>

# %%
listing_df = pd.read_csv('listings.csv')

display(listing_df.head(5))
display(listing_df.columns)
display(listing_df.shape)
# Out:
#       id                                               name  host_id
# 0   2818  Condo in Amsterdam · ★4.90 · 1 bedroom · 2 bed...     3159  \
# 1  20168  Townhouse in Amsterdam · ★4.44 · 1 bedroom · 1...    59484
# 2  27886  Houseboat in Amsterdam · ★4.93 · 1 bedroom · 1...    97647
# 3  28871  Rental unit in Amsterdam · ★4.87 · 1 bedroom ·...   124245
# 4  29051  Rental unit in Amsterdam · ★4.81 · 1 bedroom ·...   124245
#
#    host_name  neighbourhood_group                           neighbourhood
# 0     Daniel                  NaN  Oostelijk Havengebied - Indische Buurt  \
# 1  Alexander                  NaN                            Centrum-Oost
# 2       Flip                  NaN                            Centrum-West
# 3      Edwin                  NaN                            Centrum-West
# 4      Edwin                  NaN                            Centrum-Oost
#
#    latitude  longitude     room_type  price  minimum_nights
# ...

# %%
review_df = pd.read_csv('reviews.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
display(review_df.head(10))
# Out:
#    listing_id     id        date  reviewer_id reviewer_name
# 0        2818   1191  2009-03-30        10952           Lam  \
# 1        2818   1771  2009-04-24        12798         Alice
# 2        2818   1989  2009-05-03        11869       Natalja
# 3        2818   2797  2009-05-18        14064       Enrique
# 4        2818   3151  2009-05-25        17977       Sherwin
# 5        2818   4748  2009-06-29        20192           Jie
# 6        2818   5202  2009-07-07        23055       Vanessa
# 7        2818   9131  2009-09-06        26343         Katja
# 8        2818  12103  2009-10-01        40999     Marie-Eve
# 9        2818  16196  2009-11-04        38623        Graham
#
#                                             comments
# 0  Daniel is really cool. The place was nice and ...
# 1  Daniel is the most amazing host! His place is ...
# 2  We had such a great time in Amsterdam. Daniel ...
# 3  Very professional operation. Room is very clea...
# ...

# %%
550 * 70
# Out:
# 38500

# %%
import geojson
with open('neighbourhoods.geojson') as f:

    gj = geojson.load(f)
features = gj['features'][0]
len(gj['features'])
# Out:
# 22

# %%
import geopandas as gpd
earthquake = gpd.read_file('neighbourhoods.geojson')

display(earthquake.head())
type(earthquake.geometry)
# Out:
#               neighbourhood neighbourhood_group
# 0              Bijlmer-Oost                None  \
# 1                Noord-Oost                None
# 2                Noord-West                None
# 3                 Oud-Noord                None
# 4  IJburg - Zeeburgereiland                None
#
#                                             geometry
# 0  MULTIPOLYGON Z (((4.99167 52.32444 0.00000, 4....
# 1  MULTIPOLYGON Z (((5.07916 52.38865 0.00000, 5....
# 2  MULTIPOLYGON Z (((4.93072 52.41161 0.00000, 4....
# 3  MULTIPOLYGON Z (((4.95242 52.38983 0.00000, 4....
# 4  MULTIPOLYGON Z (((5.03906 52.35458 0.00000, 5....
# geopandas.geoseries.GeoSeries
